# %%
import numpy as np
import pandas as pd
import tqdm
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use('seaborn-poster')

# %% [markdown]
# # Import data

# %%
corr_df = pd.read_csv('dataset/curated/correlation.csv', index_col='token')
price_df = pd.read_csv('dataset/curated/price.csv', index_col='token')
price_df.index = pd.to_datetime(price_df.index)

# %%
corr_df
# Out:
#                 BTC       ETH      USDT       FTT       BNB       SOL  \
# token
# BTC        1.000000  0.731655  0.180708  0.769954  0.568265  0.323026
# ETH        0.731655  1.000000  0.187457  0.790834  0.573285  0.485351
# USDT       0.180708  0.187457  1.000000  0.168983  0.094633  0.020305
# FTT        0.769954  0.790834  0.168983  1.000000  0.806364  0.500536
# BNB        0.568265  0.573285  0.094633  0.806364  1.000000  0.453255
# ...             ...       ...       ...       ...       ...       ...
# ASDHEDGE  -0.316703 -0.253597  0.009438 -0.367124 -0.353150 -0.258836
# USDTHALF  -0.018515 -0.121600  0.189519 -0.104795 -0.060938 -0.156696
# PRIVHALF   0.746492  0.759472  0.088660  0.730923  0.610008  0.447291
# XAUTHALF   0.071748  0.085078  0.078449  0.051505  0.023484  0.079862
# USDTHEDGE -0.055810 -0.138143 -0.293757 -0.074786 -0.038335 -0.119781
#
#                 XRP      RUNE       LTC      LINK  ...  CUSDTHALF  CUSDTHEDGE  \
# token                                              ...
# BTC        0.469658  0.531982  0.767566  0.603389  ...   0.095912   -0.005116
# ETH        0.503247  0.631344  0.784416  0.751160  ...   0.037352   -0.005371
# USDT       0.065914  0.147177  0.149848  0.190058  ...   0.094355   -0.062414
# FTT        0.458448  0.612795  0.710810  0.678253  ...   0.061958   -0.006645
# BNB        0.416628  0.498242  0.568252  0.540328  ...   0.063891   -0.031466
# ...             ...       ...       ...       ...  ...        ...         ...
# ASDHEDGE  -0.189195 -0.182617 -0.259452 -0.233818  ...  -0.011483   -0.039379
# USDTHALF  -0.019909 -0.065979 -0.051595 -0.079173  ...   0.116438   -0.089468
# PRIVHALF   0.584404  0.560671  0.806505  0.709564  ...  -0.001943    0.031214
# XAUTHALF   0.069156  0.068035  0.085878  0.051288  ...  -0.009246    0.017668
# USDTHEDGE -0.039398 -0.145686 -0.142415 -0.147857  ...   0.018687   -0.089971
#
#            XAUTHEDGE   ASDHALF   ETCHALF  ASDHEDGE  USDTHALF  PRIVHALF  \
# token
# BTC        -0.062504  0.316103  0.456118 -0.316703 -0.018515  0.746492
# ETH        -0.171990  0.253957  0.561964 -0.253597 -0.121600  0.759472
# USDT       -0.297072 -0.018245  0.140701  0.009438  0.189519  0.088660
# FTT        -0.147566  0.370528  0.489928 -0.367124 -0.104795  0.730923
# BNB        -0.098469  0.357734  0.376508 -0.353150 -0.060938  0.610008
# ...              ...       ...       ...       ...       ...       ...
# ASDHEDGE   -0.042304 -0.974711 -0.146596  1.000000  0.066953 -0.298144
# USDTHALF    0.050176 -0.045323 -0.045762  0.066953  1.000000 -0.075544
# PRIVHALF   -0.181072  0.280474  0.640414 -0.298144 -0.075544  1.000000
# XAUTHALF   -0.621865 -0.097456  0.076841  0.095510  0.037583  0.068414
# USDTHEDGE   0.278293 -0.070691 -0.177833  0.090404  0.030867 -0.084163
#
#            XAUTHALF  USDTHEDGE
# token
# BTC        0.071748  -0.055810
# ETH        0.085078  -0.138143
# USDT       0.078449  -0.293757
# FTT        0.051505  -0.074786
# BNB        0.023484  -0.038335
# ...             ...        ...
# ASDHEDGE   0.095510   0.090404
# USDTHALF   0.037583   0.030867
# PRIVHALF   0.068414  -0.084163
# XAUTHALF   1.000000   0.045324
# USDTHEDGE  0.045324   1.000000
#
# [186 rows x 186 columns]

# %%
price_df
# Out:
#                 BTC      ETH    USDT     FTT      BNB      SOL       XRP  \
# token
# 2020-08-01  11816.0   387.39  1.0011   3.498   21.626   1.5275  0.290900
# 2020-08-02  11070.0   372.23  0.9994   3.351   20.985   1.7300  0.287575
# 2020-08-03  11234.0   386.30  1.0006   3.539   22.059   1.8000  0.310175
# 2020-08-04  11199.5   389.70  1.0003   3.475   22.308   1.8600  0.301325
# 2020-08-05  11756.5   401.22  1.0009   3.608   23.289   1.7575  0.302425
# ...             ...      ...     ...     ...      ...      ...       ...
# 2021-07-30  42232.0  2463.40  1.0004  34.980  322.924  32.3975  0.751950
# 2021-07-31  41494.0  2533.80  1.0006  35.200  332.807  36.7125  0.745950
# 2021-08-01  39847.0  2555.90  1.0004  34.929  332.783  34.1800  0.723450
# 2021-08-02  39151.0  2607.70  1.0003  37.856  330.665  33.1925  0.738475
# 2021-08-03  38633.0  2518.70  1.0001  36.564  323.600  35.0325  0.719075
#
#               RUNE      LTC     LINK  ...  CUSDTHALF  CUSDTHEDGE  XAUTHEDGE  \
# token                                 ...
# 2020-08-01  0.4470   61.745   8.3220  ...    6113.75      5982.0     4801.5
# 2020-08-02  0.4790   56.665   8.2640  ...    6109.75      5994.0     4874.0
# 2020-08-03  0.4560   58.550   9.2375  ...    6107.75      5989.5     4834.5
# 2020-08-04  0.5070   57.675   9.8485  ...    6105.00      5989.5     4702.5
# 2020-08-05  0.5595   58.880   9.5405  ...    6106.25      5987.5     4703.0
# ...            ...      ...      ...  ...        ...         ...        ...
# 2021-07-30  6.3240  145.590  22.2665  ...    5348.25      6521.0     4796.5
# 2021-07-31  6.4845  144.475  22.7140  ...    5344.25      6519.0     4793.0
# 2021-08-01  5.9970  140.260  22.0680  ...    5341.75      6521.5     4804.5
# 2021-08-02  7.3025  141.370  23.4790  ...    5339.25      6522.5     4804.5
# 2021-08-03  7.0230  139.350  23.4060  ...    5339.50      6520.0     4812.5
#
#             ASDHALF  ETCHALF  ASDHEDGE  USDTHALF  PRIVHALF  XAUTHALF  \
# token
# 2020-08-01   7840.5   7612.0  2158.000   6176.75    8385.0   6749.00
# 2020-08-02   7811.5   7278.5  2168.500   6176.75    8119.0   6696.50
# 2020-08-03   8397.5   7270.0  1849.500   6177.00    8241.0   6722.00
# 2020-08-04   8657.0   7250.0  1735.500   6177.00    8236.0   6812.00
# 2020-08-05   9008.5   7309.5  1592.400   6178.75    8496.5   6810.50
# ...             ...      ...       ...       ...       ...       ...
# 2021-07-30  19592.0  26391.0    62.590   6170.75   15942.0   6187.50
# 2021-07-31  19788.0  26484.0    61.235   6170.75   16014.0   6183.00
# 2021-08-01  19975.0  26204.0    60.080   6170.75   15879.0   6177.75
# 2021-08-02  19870.0  26499.0    60.410   6170.75   15558.0   6174.25
# 2021-08-03  19589.0  26062.0    62.460   6170.75   15417.0   6173.75
#
#             USDTHEDGE
# token
# 2020-08-01     5323.5
# 2020-08-02     5305.5
# 2020-08-03     5305.5
# 2020-08-04     5305.5
# 2020-08-05     5305.5
# ...               ...
# 2021-07-30     4534.5
# 2021-07-31     4531.5
# 2021-08-01     4529.5
# 2021-08-02     4528.5
# 2021-08-03     4528.0
#
# [368 rows x 186 columns]

# %%
asset_info_df = pd.read_csv('dataset/coingeko_marketcap.csv')
asset_info_df['symbol'] = asset_info_df['symbol'].str.upper()

asset_info_df
# Out:
#                        id  symbol                 name  \
# 0                 bitcoin     BTC              Bitcoin
# 1                ethereum     ETH             Ethereum
# 2                  tether    USDT               Tether
# 3             binancecoin     BNB         Binance Coin
# 4                 cardano     ADA              Cardano
# ...                   ...     ...                  ...
# 6038                xkncb   XKNCB                xKNCb
# 6039                imusd   IMUSD                imUSD
# 6040  wallstreetbets-coin    WSBC  WallStreetBets Coin
# 6041               dexlab     DXL               Dexlab
# 6042    sbland-vault-nftx  SBLAND  SBLAND Vault (NFTX)
#
#                                                   image  current_price  \
# 0     https://assets.coingecko.com/coins/images/1/la...   44901.000000
# 1     https://assets.coingecko.com/coins/images/279/...    3145.290000
# 2     https://assets.coingecko.com/coins/images/325/...       0.999284
# 3     https://assets.coingecko.com/coins/images/825/...     355.910000
# 4     https://assets.coingecko.com/coins/images/975/...       1.480000
# ...                                                 ...            ...
# 6038  https://assets.coingecko.com/coins/images/1399...            NaN
# 6039  https://assets.coingecko.com/coins/images/1369...            NaN
# 6040  https://assets.coingecko.com/coins/images/1608...            NaN
# 6041  https://assets.coingecko.com/coins/images/1727...            NaN
# 6042  https://assets.coingecko.com/coins/images/1705...            NaN
#
#         market_cap  market_cap_rank  fully_diluted_valuation  total_volume  \
# 0     8.432134e+11              1.0             9.429023e+11  4.360471e+10
# 1     3.680135e+11              2.0                      NaN  4.126463e+10
# 2     6.238751e+10              3.0                      NaN  8.301148e+10
# 3     5.500251e+10              4.0             6.069732e+10  1.627925e+09
# 4     4.736214e+10              5.0             6.646512e+10  2.577603e+09
# ...            ...              ...                      ...           ...
# 6038           NaN              NaN                      NaN  0.000000e+00
# 6039           NaN              NaN                      NaN  0.000000e+00
# 6040           NaN              NaN                      NaN           NaN
# 6041           NaN              NaN                      NaN           NaN
# 6042           NaN              NaN                      NaN  0.000000e+00
#
#       high_24h  ...  total_supply    max_supply       ath  \
# 0     45242.00  ...  2.100000e+07  2.100000e+07  64805.00
# 1      3178.76  ...           NaN           NaN   4356.99
# 2         1.02  ...  6.243224e+10           NaN      1.32
# 3       361.59  ...  1.705337e+08  1.705337e+08    686.31
# 4         1.49  ...  4.500000e+10  4.500000e+10      2.45
# ...        ...  ...           ...           ...       ...
# 6038       NaN  ...  8.151451e+05           NaN       NaN
# 6039       NaN  ...           NaN           NaN       NaN
# 6040       NaN  ...           NaN           NaN       NaN
# 6041       NaN  ...  1.000000e+09           NaN       NaN
# 6042       NaN  ...  6.000000e+00           NaN       NaN
#
#       ath_change_percentage                  ath_date        atl  \
# 0                 -30.71318  2021-04-14T11:54:46.763Z  67.810000
# 1                 -27.81051  2021-05-12T14:41:48.623Z   0.432979
# 2                 -24.47380  2018-07-24T00:00:00.000Z   0.572521
# 3                 -48.13340  2021-05-10T07:24:17.097Z   0.039818
# 4                 -39.60002  2021-05-16T07:44:28.033Z   0.019253
# ...                     ...                       ...        ...
# 6038                0.00000                       NaN        NaN
# 6039                0.00000                       NaN        NaN
# 6040                0.00000                       NaN        NaN
# 6041                0.00000                       NaN        NaN
# 6042                0.00000                       NaN        NaN
#
#       atl_change_percentage                  atl_date  \
# 0               66117.06502  2013-07-06T00:00:00.000Z
# 1              726330.22912  2015-10-20T00:00:00.000Z
# 2                  74.54096  2015-03-02T00:00:00.000Z
# 3              893884.11189  2017-10-19T00:00:00.000Z
# 4                7571.99082  2020-03-13T02:22:55.044Z
# ...                     ...                       ...
# 6038                0.00000                       NaN
# 6039                0.00000                       NaN
# 6040                0.00000                       NaN
# 6041                0.00000                       NaN
# 6042                0.00000                       NaN
#
#                                                     roi  \
# 0                                                   NaN
# 1     {'times': 92.67582986335988, 'currency': 'btc'...
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 6038                                                NaN
# 6039                                                NaN
# 6040                                                NaN
# 6041                                                NaN
# 6042                                                NaN
#
#                   last_updated
# 0     2021-08-08T08:19:02.743Z
# 1     2021-08-08T08:19:00.968Z
# 2     2021-08-08T08:06:12.204Z
# 3     2021-08-08T08:19:00.986Z
# 4     2021-08-08T08:20:05.942Z
# ...                        ...
# 6038  2021-08-04T06:39:01.434Z
# 6039  2021-08-06T14:30:29.182Z
# 6040                       NaN
# 6041                       NaN
# 6042  2021-08-07T00:05:45.828Z
#
# [6043 rows x 26 columns]

# %%
market_cap_df = pd.DataFrame(corr_df.index.tolist(), columns=['symbol'])
market_cap_df = market_cap_df.merge(asset_info_df[['symbol', 'market_cap']],
                    how='left', 
                    on='symbol'
                   )
market_caps = market_cap_df.set_index('symbol')['market_cap']
market_caps
# Out:
# symbol
# BTC          8.432134e+11
# ETH          3.680135e+11
# USDT         6.238751e+10
# FTT          4.840712e+09
# BNB          5.500251e+10
#                  ...
# ASDHEDGE              NaN
# USDTHALF              NaN
# PRIVHALF              NaN
# XAUTHALF              NaN
# USDTHEDGE             NaN
# Name: market_cap, Length: 186, dtype: float64

# %% [markdown]
# ## Filter only selected assets

# %%
ASSETS = ['BTC', 'ETH', 'FTT', 'BNB',
          'SOL', 'XRP', 'RUNE', 'LTC', 
          'LINK', 'BCH', 'SXP', 'COMP', 
          'TRYB', 'YFI', 'MKR', 'TRX', 
          'PAXG', 'AMPL', 'KNC', 'BAL', 
          'MTA', 'WRX', 'ASD', 'DMG'
         ]

# %%
corr_df = corr_df.loc[corr_df.index.isin(ASSETS), corr_df.columns.isin(ASSETS)] # Filter only selected assets
corr_df
# Out:
#             BTC       ETH       FTT       BNB       SOL       XRP      RUNE  \
# token
# BTC    1.000000  0.731655  0.769954  0.568265  0.323026  0.469658  0.531982
# ETH    0.731655  1.000000  0.790834  0.573285  0.485351  0.503247  0.631344
# FTT    0.769954  0.790834  1.000000  0.806364  0.500536  0.458448  0.612795
# BNB    0.568265  0.573285  0.806364  1.000000  0.453255  0.416628  0.498242
# SOL    0.323026  0.485351  0.500536  0.453255  1.000000  0.339221  0.495796
# XRP    0.469658  0.503247  0.458448  0.416628  0.339221  1.000000  0.354629
# RUNE   0.531982  0.631344  0.612795  0.498242  0.495796  0.354629  1.000000
# LTC    0.767566  0.784416  0.710810  0.568252  0.379898  0.573773  0.550695
# LINK   0.603389  0.751160  0.678253  0.540328  0.476556  0.491401  0.651004
# BCH    0.668583  0.725200  0.635101  0.508774  0.328554  0.553836  0.486166
# SXP    0.531243  0.573013  0.594239  0.537038  0.511995  0.507003  0.547388
# COMP   0.522076  0.662675  0.569214  0.454134  0.428887  0.420171  0.556875
# TRYB   0.290649  0.234672  0.266105  0.211758  0.038083  0.087365  0.144190
# YFI    0.430579  0.541293  0.495940  0.370820  0.473647  0.373975  0.466512
# MKR    0.495851  0.682646  0.551863  0.446169  0.383929  0.391670  0.469116
# TRX    0.558160  0.618866  0.575369  0.488075  0.344261  0.551128  0.478460
# PAXG   0.107543  0.083702  0.102842  0.033182  0.034660  0.003663  0.097282
# AMPL   0.357824  0.465284  0.405463  0.292251  0.263212  0.202101  0.334500
# KNC    0.538630  0.619166  0.609839  0.531288  0.414664  0.490032  0.532433
# BAL    0.512722  0.680976  0.589579  0.411198  0.430537  0.376152  0.584570
# MTA    0.357690  0.504731  0.431081  0.298713  0.335723  0.265655  0.445314
# WRX    0.385868  0.446072  0.481828  0.446704  0.291558  0.320908  0.354087
# ASD    0.324001  0.262740  0.377098  0.369007  0.300276  0.209076  0.192602
# DMG   -0.052837 -0.046978 -0.071597 -0.071539 -0.031827 -0.045194 -0.025549
#
#             LTC      LINK       BCH  ...       MKR       TRX      PAXG  \
# token                                ...
# BTC    0.767566  0.603389  0.668583  ...  0.495851  0.558160  0.107543
# ETH    0.784416  0.751160  0.725200  ...  0.682646  0.618866  0.083702
# FTT    0.710810  0.678253  0.635101  ...  0.551863  0.575369  0.102842
# BNB    0.568252  0.540328  0.508774  ...  0.446169  0.488075  0.033182
# SOL    0.379898  0.476556  0.328554  ...  0.383929  0.344261  0.034660
# XRP    0.573773  0.491401  0.553836  ...  0.391670  0.551128  0.003663
# RUNE   0.550695  0.651004  0.486166  ...  0.469116  0.478460  0.097282
# LTC    1.000000  0.703099  0.806718  ...  0.536028  0.614780  0.114223
# LINK   0.703099  1.000000  0.659856  ...  0.594556  0.561571  0.058617
# BCH    0.806718  0.659856  1.000000  ...  0.569166  0.636078  0.079662
# SXP    0.578293  0.638542  0.536070  ...  0.459236  0.527860  0.029985
# COMP   0.551923  0.610854  0.546537  ...  0.624359  0.496208  0.038271
# TRYB   0.225359  0.137245  0.157383  ...  0.173785  0.146596  0.020436
# YFI    0.510047  0.492863  0.456996  ...  0.408886  0.439319  0.080492
# MKR    0.536028  0.594556  0.569166  ...  1.000000  0.444206  0.051620
# TRX    0.614780  0.561571  0.636078  ...  0.444206  1.000000  0.083884
# PAXG   0.114223  0.058617  0.079662  ...  0.051620  0.083884  1.000000
# AMPL   0.390369  0.376956  0.326346  ...  0.311652  0.265683  0.053123
# KNC    0.618476  0.650913  0.570845  ...  0.537120  0.534045  0.047873
# BAL    0.549180  0.679851  0.508762  ...  0.537303  0.461176  0.125478
# MTA    0.411410  0.487030  0.349088  ...  0.426570  0.343071  0.053652
# WRX    0.411748  0.409645  0.395398  ...  0.354753  0.459252  0.035411
# ASD    0.260726  0.246547  0.214901  ...  0.242703  0.269591 -0.090359
# DMG   -0.086417 -0.024721 -0.077485  ... -0.047863 -0.058022  0.034561
#
#            AMPL       KNC       BAL       MTA       WRX       ASD       DMG
# token
# BTC    0.357824  0.538630  0.512722  0.357690  0.385868  0.324001 -0.052837
# ETH    0.465284  0.619166  0.680976  0.504731  0.446072  0.262740 -0.046978
# FTT    0.405463  0.609839  0.589579  0.431081  0.481828  0.377098 -0.071597
# BNB    0.292251  0.531288  0.411198  0.298713  0.446704  0.369007 -0.071539
# SOL    0.263212  0.414664  0.430537  0.335723  0.291558  0.300276 -0.031827
# XRP    0.202101  0.490032  0.376152  0.265655  0.320908  0.209076 -0.045194
# RUNE   0.334500  0.532433  0.584570  0.445314  0.354087  0.192602 -0.025549
# LTC    0.390369  0.618476  0.549180  0.411410  0.411748  0.260726 -0.086417
# LINK   0.376956  0.650913  0.679851  0.487030  0.409645  0.246547 -0.024721
# BCH    0.326346  0.570845  0.508762  0.349088  0.395398  0.214901 -0.077485
# SXP    0.261220  0.605850  0.544551  0.373689  0.477114  0.351127 -0.115947
# COMP   0.367728  0.566912  0.611278  0.443203  0.375091  0.229075 -0.038373
# TRYB   0.092005  0.164290  0.149077  0.064250  0.117374  0.079170 -0.021363
# YFI    0.346415  0.415178  0.481056  0.366129  0.323573  0.164316  0.000068
# MKR    0.311652  0.537120  0.537303  0.426570  0.354753  0.242703 -0.047863
# TRX    0.265683  0.534045  0.461176  0.343071  0.459252  0.269591 -0.058022
# PAXG   0.053123  0.047873  0.125478  0.053652  0.035411 -0.090359  0.034561
# AMPL   1.000000  0.345851  0.441669  0.329161  0.221914  0.114534  0.028035
# KNC    0.345851  1.000000  0.586092  0.405972  0.386276  0.261848 -0.086722
# BAL    0.441669  0.586092  1.000000  0.548847  0.344661  0.246417 -0.006200
# MTA    0.329161  0.405972  0.548847  1.000000  0.201342  0.217023 -0.003247
# WRX    0.221914  0.386276  0.344661  0.201342  1.000000  0.204851  0.004480
# ASD    0.114534  0.261848  0.246417  0.217023  0.204851  1.000000  0.004784
# DMG    0.028035 -0.086722 -0.006200 -0.003247  0.004480  0.004784  1.000000
#
# [24 rows x 24 columns]

# %%
plt.subplots(figsize=(9, 6))
sns.heatmap(corr_df)

# %%
price_df = price_df.loc[:, price_df.columns.isin(ASSETS)] # Filter only selected assets
price_df
# Out:
#                 BTC      ETH     FTT      BNB      SOL       XRP    RUNE  \
# token
# 2020-08-01  11816.0   387.39   3.498   21.626   1.5275  0.290900  0.4470
# 2020-08-02  11070.0   372.23   3.351   20.985   1.7300  0.287575  0.4790
# 2020-08-03  11234.0   386.30   3.539   22.059   1.8000  0.310175  0.4560
# 2020-08-04  11199.5   389.70   3.475   22.308   1.8600  0.301325  0.5070
# 2020-08-05  11756.5   401.22   3.608   23.289   1.7575  0.302425  0.5595
# ...             ...      ...     ...      ...      ...       ...     ...
# 2021-07-30  42232.0  2463.40  34.980  322.924  32.3975  0.751950  6.3240
# 2021-07-31  41494.0  2533.80  35.200  332.807  36.7125  0.745950  6.4845
# 2021-08-01  39847.0  2555.90  34.929  332.783  34.1800  0.723450  5.9970
# 2021-08-02  39151.0  2607.70  37.856  330.665  33.1925  0.738475  7.3025
# 2021-08-03  38633.0  2518.70  36.564  323.600  35.0325  0.719075  7.0230
#
#                 LTC     LINK      BCH  ...     MKR       TRX    PAXG    AMPL  \
# token                                  ...
# 2020-08-01   61.745   8.3220  319.550  ...   592.5  0.020485  1983.7  1.3775
# 2020-08-02   56.665   8.2640  283.650  ...   568.5  0.019072  1987.3  1.0200
# 2020-08-03   58.550   9.2375  296.900  ...   591.0  0.019903  1986.4  0.8955
# 2020-08-04   57.675   9.8485  288.000  ...   583.5  0.020383  2035.0  0.7895
# 2020-08-05   58.880   9.5405  293.675  ...   591.0  0.020315  2051.6  0.8058
# ...             ...      ...      ...  ...     ...       ...     ...     ...
# 2021-07-30  145.590  22.2665  552.725  ...  2916.0  0.063207  1822.6  0.8888
# 2021-07-31  144.475  22.7140  546.500  ...  2977.5  0.063922  1820.9  0.9736
# 2021-08-01  140.260  22.0680  526.925  ...  2885.5  0.063260  1815.6  1.0180
# 2021-08-02  141.370  23.4790  543.650  ...  2915.5  0.064620  1815.7  0.9621
# 2021-08-03  139.350  23.4060  537.525  ...  2818.5  0.064375  1814.3  0.9555
#
#                KNC      BAL     MTA      WRX      ASD    DMG
# token
# 2020-08-01  1.4817  10.7200  5.0000  0.12420  0.05624  1.129
# 2020-08-02  1.4090  10.2125  4.4240  0.12127  0.05730  1.068
# 2020-08-03  1.3858  10.4475  5.2040  0.12250  0.06555  1.085
# 2020-08-04  1.4794  10.3775  5.5190  0.12324  0.06993  1.150
# 2020-08-05  1.5309   9.9900  4.8730  0.12826  0.07553  1.246
# ...            ...      ...     ...      ...      ...    ...
# 2021-07-30  1.5678  20.6125  0.7535  1.13580  0.35202  0.047
# 2021-07-31  1.6307  21.7525  0.7960  1.12798  0.35868  0.048
# 2021-08-01  1.5573  21.2425  0.8030  1.08387  0.36573  0.046
# 2021-08-02  1.6085  21.8925  0.8130  1.08964  0.36194  0.046
# 2021-08-03  1.5736  21.1975  0.7705  1.06102  0.35144  0.047
#
# [368 rows x 24 columns]

# %%
market_caps = market_caps.loc[ASSETS] # Filter only selected assets
market_caps
# Out:
# symbol
# BTC     8.432134e+11
# ETH     3.680135e+11
# FTT     4.840712e+09
# BNB     5.500251e+10
# SOL     1.060715e+10
# XRP     3.821842e+10
# RUNE    1.990675e+09
# LTC     1.037442e+10
# LINK    1.094700e+10
# BCH     1.091427e+10
# SXP     2.258085e+08
# COMP    2.698483e+09
# TRYB    7.966098e+07
# YFI     1.225168e+09
# MKR     3.068436e+09
# TRX     5.419969e+09
# PAXG    2.977072e+08
# AMPL    2.103903e+08
# KNC     1.799069e+08
# BAL     2.784054e+08
# MTA     2.944088e+07
# WRX     5.523514e+08
# ASD     2.766178e+08
# DMG     2.586578e+06
# Name: market_cap, dtype: float64

# %% [markdown]
# # Asset allocation

# %%
from pypfopt import black_litterman
from pypfopt.black_litterman import BlackLittermanModel
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import objective_functions

# %%
market_caps.plot(kind='pie',
                 figsize=(8, 8),
                 autopct='%1.1f%%',
                 label='Market Cap'
                )

# %%
experiments = pd.DataFrame(index=ASSETS)
experiments
# Out:
# Empty DataFrame
# Columns: []
# Index: [BTC, ETH, FTT, BNB, SOL, XRP, RUNE, LTC, LINK, BCH, SXP, COMP, TRYB, YFI, MKR, TRX, PAXG, AMPL, KNC, BAL, MTA, WRX, ASD, DMG]

# %% [markdown]
# ## BTC Only (Baseline)

# %%
BTC_ONLY_PORTFOLIO = 'Buy & Hold BTC'
buy_hold_btc_weights = pd.Series(np.zeros(len(ASSETS)), index=ASSETS)
buy_hold_btc_weights.loc['BTC'] = 1.0
experiments[BTC_ONLY_PORTFOLIO] = buy_hold_btc_weights
buy_hold_btc_weights
# Out:
# BTC     1.0
# ETH     0.0
# FTT     0.0
# BNB     0.0
# SOL     0.0
# XRP     0.0
# RUNE    0.0
# LTC     0.0
# LINK    0.0
# BCH     0.0
# SXP     0.0
# COMP    0.0
# TRYB    0.0
# YFI     0.0
# MKR     0.0
# TRX     0.0
# PAXG    0.0
# AMPL    0.0
# KNC     0.0
# BAL     0.0
# MTA     0.0
# WRX     0.0
# ASD     0.0
# DMG     0.0
# dtype: float64

# %%
experiments[BTC_ONLY_PORTFOLIO].plot.pie(
                                       figsize=(8, 8),
                                       autopct='%1.1f%%',
                                       label='Portfolio Allocation')

# %% [markdown]
# ## Market-implied return Allocation

# %%
MARKET_IMPLIED_RETURN_PORTFOLIO = 'Market-implied return + Maximize Sharpe ratio'

# %% [markdown]
# ### Use BTC as market index

# %%
market_index_prices = price_df['BTC']
delta = black_litterman.market_implied_risk_aversion(market_index_prices, frequency=len(price_df))
prior = black_litterman.market_implied_prior_returns(market_caps, delta, corr_df)

# %%
delta
# Out:
# 2.4019056249836903

# %%
prior
# Out:
# token
# BTC     2.124227
# ETH     1.913624
# FTT     1.850614
# BNB     1.414476
# SOL     0.934430
# XRP     1.200430
# RUNE    1.348651
# LTC     1.831880
# LINK    1.558693
# BCH     1.637712
# SXP     1.324307
# COMP    1.354731
# TRYB    0.645442
# YFI     1.121618
# MKR     1.324227
# TRX     1.393403
# PAXG    0.245293
# AMPL    0.929690
# KNC     1.363627
# BAL     1.344131
# MTA     0.966427
# WRX     0.987852
# ASD     0.748195
# DMG    -0.104317
# dtype: float64

# %% [markdown]
# ### Maximize Sharpe ratio
# penalty with L2 Regularization

# %%
ef = EfficientFrontier(prior, corr_df.values)
ef.add_objective(objective_functions.L2_reg)
ef.max_sharpe()

experiments[MARKET_IMPLIED_RETURN_PORTFOLIO] = pd.Series(ef.clean_weights())
experiments[MARKET_IMPLIED_RETURN_PORTFOLIO]
# Out:
# /usr/local/lib/python3.9/site-packages/pypfopt/efficient_frontier/efficient_frontier.py:252: UserWarning: max_sharpe transforms the optimization problem so additional objectives may not work as expected.
#   warnings.warn(
# BTC     0.20816
# ETH     0.10693
# FTT     0.09211
# BNB     0.04141
# SOL     0.00142
# XRP     0.03415
# RUNE    0.03282
# LTC     0.08892
# LINK    0.03663
# BCH     0.06161
# SXP     0.02004
# COMP    0.02720
# TRYB    0.03217
# YFI     0.01746
# MKR     0.03225
# TRX     0.03710
# PAXG    0.00941
# AMPL    0.02438
# KNC     0.02089
# BAL     0.02568
# MTA     0.01184
# WRX     0.01477
# ASD     0.02265
# DMG     0.00000
# Name: Market-implied return + Maximize Sharpe ratio, dtype: float64

# %%
experiments[MARKET_IMPLIED_RETURN_PORTFOLIO].plot.pie(
                                               figsize=(8, 8),
                                               autopct='%1.1f%%',
                                               label='Portfolio Allocation')

# %% [markdown]
# ## Black-Litterman Allocation

# %% [markdown]
# ### Use BTC as market index

# %%
market_index_prices = price_df['BTC']
delta = black_litterman.market_implied_risk_aversion(market_index_prices, frequency=len(price_df))
prior = black_litterman.market_implied_prior_returns(market_caps, delta, corr_df)

# %%
delta
# Out:
# 2.4019056249836903

# %%
prior
# Out:
# token
# BTC     2.124227
# ETH     1.913624
# FTT     1.850614
# BNB     1.414476
# SOL     0.934430
# XRP     1.200430
# RUNE    1.348651
# LTC     1.831880
# LINK    1.558693
# BCH     1.637712
# SXP     1.324307
# COMP    1.354731
# TRYB    0.645442
# YFI     1.121618
# MKR     1.324227
# TRX     1.393403
# PAXG    0.245293
# AMPL    0.929690
# KNC     1.363627
# BAL     1.344131
# MTA     0.966427
# WRX     0.987852
# ASD     0.748195
# DMG    -0.104317
# dtype: float64

# %%
bl = BlackLittermanModel(corr_df,
                         Q=np.zeros(len(ASSETS),),
                         pi='market',
                          market_caps=market_caps,
                         risk_aversion=delta
                        )

# %%
pd.Series(bl.bl_weights())
# Out:
# BTC     38.844521
# ETH     15.443390
# FTT     -8.310692
# BNB     -0.077249
# SOL      0.601244
# XRP     -0.559976
# RUNE    -2.944410
# LTC     -7.626725
# LINK    -2.683290
# BCH     -5.026083
# SXP     -1.859621
# COMP    -2.366385
# TRYB    -3.014841
# YFI     -1.556524
# MKR     -2.814505
# TRX     -3.106242
# PAXG    -0.864594
# AMPL    -2.277344
# KNC     -1.945530
# BAL     -2.393560
# MTA     -1.110493
# WRX     -1.350914
# ASD     -2.109354
# DMG      0.109175
# dtype: float64

# %% [markdown]
# # Visualization

# %%
portfolio_weight_df = experiments.copy()
init_price = price_df.iloc[0]
position_size_df = portfolio_weight_df.div(init_price, axis=0)
        
portfolio_value_df = position_size_df.apply(lambda weights: (price_df*weights).sum(axis=1))

# %%
class PortfolioBacktester:
    def __init__(self, price_df, portfolio_weight_df):
        self.price_df = price_df
        self.portfolio_weight_df = portfolio_weight_df
        
        self.calculate_portfolio_value()
    def calculate_portfolio_value(self):
        init_price = self.price_df.iloc[0]
        self.position_size_df = self.portfolio_weight_df.div(init_price, axis=0)

        self.portfolio_value_df = self.position_size_df.apply(lambda weights: (self.price_df*weights).sum(axis=1))
        
    def plot_value(self, name=None, **kwargs):
        self.portfolio_value_df.plot(**kwargs)
    
    def plot_value_area(self, portfolio_name=None, **kwargs):
        if portfolio_name is not None:
            asset_value_df = self.price_df * self.position_size_df[portfolio_name]
            asset_value_df.plot.area(title=portfolio_name, **kwargs)
        else:
            fig, axes = plt.subplots(len(self.portfolio_weight_df.columns))
            for ax, portfolio_name in zip(axes, self.portfolio_weight_df.columns):
                asset_value_df = self.price_df * self.position_size_df[portfolio_name]
                asset_value_df.plot.area(title=portfolio_name, ax=ax, **kwargs)

portfolio_backtester = PortfolioBacktester(price_df, experiments)

# %%
portfolio_backtester.plot_value(figsize=(16, 6))

# %%
portfolio_backtester.plot_value_area(figsize=(16, 18))
